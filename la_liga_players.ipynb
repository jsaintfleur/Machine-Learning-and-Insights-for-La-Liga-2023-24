# %%
# General libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import FancyBboxPatch
import seaborn as sns

# Machine Learning and Forecasting
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from statsmodels.tsa.seasonal import seasonal_decompose

# Time Series Forecasting
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima

# Clustering and Dimensionality Reduction
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# Miscellaneous
import warnings

# %%
import os
import pandas as pd

# Path to the directory containing the player stats CSV files
data_dir = "FIFA_datasets/laliga2023_34/player_stats"

# List all CSV files in the directory
csv_files = [file for file in os.listdir(data_dir) if file.endswith(".csv")]

# Categorize the files into groups based on their metrics
stat_groups = {
    "defensive_stats": [
        "player_clean_sheets.csv", "player_interceptions.csv", "player_effective_clearances.csv",
        "player_tackles_won.csv", "player_outfielder_blocks.csv", "player_saves_made.csv",
        "player_goals_conceded.csv", "player_penalties_conceded.csv"
    ],
    "attacking_stats": [
        "player_top_scorers.csv", "player_shots_per_90.csv", "player_on_target_scoring_attempts.csv",
        "player_shots_on_target_per_90.csv", "player_big_chances_created.csv",
        "player_big_chances_missed.csv"
    ],
    "expected_stats": [
        "player_expected_goals.csv", "player_expected_goals_per_90.csv", "player_expected_assists.csv",
        "player_expected_assists_per_90.csv", "player_expected_goals_on_target.csv"
    ],
    "misc_stats": [
        "player_yellow_cards.csv", "player_red_cards.csv", "player_player_ratings.csv",
        "player_penalties_won.csv", "player_possessions_won_attacking_third.csv"
    ]
}

# Function to load and combine CSV files for each stat group
def combine_stat_group(stat_files, group_name, suffix):
    group_dfs = []
    for file in stat_files:
        file_path = os.path.join(data_dir, file)
        if os.path.exists(file_path):
            df = pd.read_csv(file_path)
            group_dfs.append(df)
        else:
            print(f"Warning: File '{file}' not found in directory '{data_dir}'")
    combined_df = pd.concat(group_dfs, ignore_index=True)
    combined_df = combined_df.add_suffix(suffix).rename(
        columns={f"Player{suffix}": "Player", f"Team{suffix}": "Team"}
    )
    print(f"Combined {group_name} DataFrame created with shape: {combined_df.shape}")
    return combined_df

# Combine stats for each group with appropriate suffixes
defensive_df = combine_stat_group(stat_groups["defensive_stats"], "Defensive Stats", "_defensive")
attacking_df = combine_stat_group(stat_groups["attacking_stats"], "Attacking Stats", "_attacking")
expected_df = combine_stat_group(stat_groups["expected_stats"], "Expected Stats", "_expected")
misc_df = combine_stat_group(stat_groups["misc_stats"], "Miscellaneous Stats", "_misc")

# Merge all groups into a master DataFrame
master_df = (
    defensive_df.merge(attacking_df, on=["Player", "Team"], how="outer", suffixes=("_defensive", "_attacking"))
    .merge(expected_df, on=["Player", "Team"], how="outer", suffixes=("", "_expected"))
    .merge(misc_df, on=["Player", "Team"], how="outer", suffixes=("", "_misc"))
)

# Save the merged DataFrame to a CSV file
output_file_path = "master_player_stats_full_outer.csv"
master_df.to_csv(output_file_path, index=False)
print(f"\nMaster dataset saved to '{output_file_path}'")

# Display the final DataFrame shape
print(f"\nFinal Master DataFrame Shape: {master_df.shape}")
# Out:
# Combined Defensive Stats DataFrame created with shape: (1404, 22)
# Warning: File 'player_shots_per_90.csv' not found in directory 'FIFA_datasets/laliga2023_34/player_stats'
# Warning: File 'player_shots_on_target_per_90.csv' not found in directory 'FIFA_datasets/laliga2023_34/player_stats'
# Combined Attacking Stats DataFrame created with shape: (1200, 14)
# Combined Expected Stats DataFrame created with shape: (2134, 15)
# Combined Miscellaneous Stats DataFrame created with shape: (1203, 14)
#
# Master dataset saved to 'master_player_stats_full_outer.csv'
#
# Final Master DataFrame Shape: (65815, 59)

# %%
overall_df.head(100)
# Out:
#      Rank                 Player            Team  \
# 0   273.0       Abdelkabir Abqar          Alavés
# 1   104.0    Abderrahman Rebbach          Alavés
# 2   200.0  Abdessamad Ezzalzouli      Real Betis
# 3   182.0            Abdon Prats        Mallorca
# 4   279.0            Abdul Mumin  Rayo Vallecano
# ..    ...                    ...             ...
# 95   64.0           Fermin Lopez       Barcelona
# 96   78.0          Ferran Torres       Barcelona
# 97    NaN        Filip Jörgensen      Villarreal
# 98  244.0        Florian Lejeune  Rayo Vallecano
# 99  156.0           Fran Beltrán   Celta de Vigo
#
#     Possessions Won in Final 3rd per 90  Possessions Won Midfield per 90  \
# 0                                   0.1                              1.5
# 1                                   0.6                              1.5
# 2                                   0.3                              2.0
# 3                                   0.4                              1.4
# 4                                   0.1                              1.2
# ..                                  ...                              ...
# 95                                  0.7                              2.4
# 96                                  0.7                              1.5
# 97                                  NaN                              NaN
# 98                                  0.2                              1.6
# 99                                  0.4                              3.3
#
#     Minutes  Matches Country  Rank_overall_1  FotMob Rating  \
# 0    2314.0     27.0     MAR           224.0           6.69
# 1     713.0     23.0     ALG           305.0           6.32
# 2     921.0     28.0     MAR           293.0           6.42
# 3    1258.0     34.0     ESP           288.0           6.45
# 4    1695.0     20.0     GHA           190.0           6.76
# ..      ...      ...     ...             ...            ...
# 95   1444.0     31.0     ESP           140.0           6.87
# 96   1204.0     29.0     ESP           187.0           6.78
# 97      NaN      NaN     NaN           234.0           6.65
# 98   3328.0     37.0     FRA           117.0           6.92
# 99   2438.0     33.0     ESP           195.0           6.75
#
#     Player of the Match Awards  Minutes_overall_1  Matches_overall_1  \
# 0                          0.0             2314.0               27.0
# 1                          0.0              713.0               23.0
# 2                          0.0              921.0               28.0
# 3                          0.0             1258.0               34.0
# 4                          0.0             1695.0               20.0
# ..                         ...                ...                ...
# 95                         1.0             1444.0               31.0
# 96                         1.0             1204.0               29.0
# 97                         2.0             3240.0               36.0
# 98                         3.0             3328.0               37.0
# 99                         1.0             2438.0               33.0
#
#    Country_overall_1
# 0                MAR
# 1                ALG
# 2                MAR
# 3                ESP
# 4                GHA
# ..               ...
# 95               ESP
# 96               ESP
# 97               DEN
# 98               FRA
# 99               ESP
#
# [100 rows x 14 columns]

# %%
passing_df.head(50)
# Out:
#     Rank_passing_x                 Player                Team  \
# 0              248       Abdelkabir Abqar              Alavés
# 1              314    Abderrahman Rebbach              Alavés
# 2              230  Abdessamad Ezzalzouli          Real Betis
# 3              329            Abdon Prats            Mallorca
# 4              150            Abdul Mumin      Rayo Vallecano
# 5              160                  Abner          Real Betis
# 6              200          Adrià Pedrosa             Sevilla
# 7              262         Adrián Embarba             Almería
# 8              162            Aihen Munoz       Real Sociedad
# 9              159             Aimar Oroz             Osasuna
# 10              64          Aitor Paredes       Athletic Club
# 11             188        Alberto Moleiro          Las Palmas
# 12             176         Alberto Moreno          Villarreal
# 13              10           Aleix Garcia              Girona
# 14              99       Alejandro Catena             Osasuna
# 15             157         Alejandro Pozo             Almería
# 16             272         Alex Berenguer       Athletic Club
# 17             232            Alex Remiro       Real Sociedad
# 18             295              Alex Sola              Alavés
# 19              56            Alex Suárez          Las Palmas
# 20             311      Alexander Sørloth          Villarreal
# 21             177         Alfonso Espino      Rayo Vallecano
# 22             193        Alfonso Pedraza          Villarreal
# 23             324    Anastasios Douvikas       Celta de Vigo
# 24             240      Ander Barrenetxea       Real Sociedad
# 25             144          Ander Guevara              Alavés
# 26              28          Ander Herrera       Athletic Club
# 27             220       Andoni Gorosabel              Alavés
# 28              16    Andreas Christensen           Barcelona
# 29             235           Andriy Lunin         Real Madrid
# 30             291            André Silva       Real Sociedad
# 31             332           Ante Budimir             Osasuna
# 32             320         Anthony Lozano             Almería
# 33             137      Antoine Griezmann  Atlético de Madrid
# 34             181         Antonio Blanco              Alavés
# 35             277        Antonio Puertas          Granada CF
# 36              90         Antonio Raillo            Mallorca
# 37              34        Antonio Rüdiger         Real Madrid
# 38             293         Antonio Sivera              Alavés
# 39             243        Antonio Sánchez            Mallorca
# 40             127      Aridane Hernández      Rayo Vallecano
# 41              42         Arnau Martinez              Girona
# 42             209        Arsen Zakharyan       Real Sociedad
# 43             328           Artem Dovbyk              Girona
# 44              21    Aurélien Tchouaméni         Real Madrid
# 45              33            Axel Witsel  Atlético de Madrid
# 46             242            Ayoze Pérez          Real Betis
# 47             239                   Bebé      Rayo Vallecano
# 48              92           Benat Prados       Athletic Club
# 49             158       Benat Turrientes       Real Sociedad
#
#     Accurate Passes per 90_passing  Pass Success (%)_passing  \
# 0                             21.4                      72.9
# 1                             12.5                      66.9
# 2                             23.9                      72.3
# 3                              9.4                      56.7
# 4                             32.7                      80.2
# 5                             31.8                      81.0
# 6                             26.9                      78.6
# 7                             20.1                      75.6
# 8                             31.4                      77.3
# 9                             31.8                      82.2
# 10                            44.2                      85.6
# 11                            28.3                      81.8
# 12                            30.0                      83.5
# 13                            70.3                      91.7
# 14                            38.8                      81.9
# 15                            32.0                      76.8
# 16                            18.5                      73.2
# 17                            23.5                      74.9
# 18                            15.8                      71.7
# 19                            45.0                      87.4
# 20                            12.8                      76.6
# 21                            29.9                      75.1
# 22                            27.7                      78.9
# 23                            10.6                      63.4
# 24                            22.7                      72.5
# 25                            33.9                      76.0
# 26                            56.1                      86.6
# 27                            24.7                      82.0
# 28                            66.7                      94.3
# 29                            23.1                      85.2
# 30                            16.2                      81.9
# 31                             8.6                      54.8
# 32                            11.1                      73.3
# 33                            34.9                      82.7
# 34                            29.7                      77.9
# 35                            18.0                      77.8
# 36                            40.5                      85.8
# 37                            53.8                      90.0
# 38                            15.9                      54.7
# 39                            22.1                      73.5
# 40                            35.8                      85.8
# 41                            48.8                      89.9
# 42                            25.6                      77.1
# 43                             9.6                      71.8
# 44                            62.1                      92.0
# 45                            54.2                      92.2
# 46                            22.1                      79.7
# 47                            22.8                      72.1
# 48                            40.5                      83.4
# 49                            31.8                      87.2
#
#     Minutes_passing_x  Matches_passing_x Country_passing_x  Rank_passing_y  \
# 0                2314                 27               MAR            46.0
# 1                 713                 23               ALG           264.0
# 2                 921                 28               MAR           274.0
# 3                1258                 34               ESP           270.0
# 4                1695                 20               GHA            54.0
# 5                1397                 23               BRA           190.0
# 6                1749                 31               ESP           218.0
# 7                2485                 36               ESP           198.0
# 8                1120                 21               ESP           153.0
# 9                2350                 33               ESP           225.0
# 10               2706                 34               ESP            42.0
# 11               1807                 28               ESP           292.0
# 12               1490                 27               ESP            65.0
# 13               3201                 37               ESP             3.0
# 14               2536                 30               ESP             4.0
# 15                970                 21               ESP           130.0
# 16               1581                 35               ESP           239.0
# 17               3276                 37               ESP             NaN
# 18               1285                 31               ESP           265.0
# 19               2566                 32               ESP            77.0
# 20               2491                 34               NOR           311.0
# 21               2512                 31               URU           166.0
# 22               1119                 19               ESP           232.0
# 23                886                 32               GRE           303.0
# 24               1436                 29               ESP           237.0
# 25               2936                 37               ESP           126.0
# 26               1023                 23               ESP            83.0
# 27               2863                 36               ESP           228.0
# 28               1990                 30               DEN           100.0
# 29               1890                 21               UKR             NaN
# 30                730                 19               POR           298.0
# 31               2449                 33               CRO           315.0
# 32                866                 19               HON           303.0
# 33               2654                 33               FRA           134.0
# 34               2436                 33               ESP            84.0
# 35                720                 27               ESP           233.0
# 36               2198                 26               ESP            76.0
# 37               2707                 33               GER            78.0
# 38               3060                 34               ESP             NaN
# 39               1463                 29               ESP           189.0
# 40               1691                 19               EQG            66.0
# 41               1240                 21               ESP           240.0
# 42               1229                 29               RUS           199.0
# 43               2605                 36               UKR           308.0
# 44               1987                 27               FRA            91.0
# 45               2784                 35               BEL           113.0
# 46               2307                 31               ESP           282.0
# 47                193                 19               CPV            95.0
# 48               1450                 26               ESP           213.0
# 49               1688                 29               ESP           122.0
#
#     Accurate Long Balls per 90_passing  Successful Long Balls (%)_passing  \
# 0                                  3.1                               36.9
# 1                                  0.6                               41.7
# 2                                  0.5                               38.5
# 3                                  0.5                               53.8
# 4                                  2.9                               37.4
# 5                                  1.3                               37.0
# 6                                  1.1                               29.3
# 7                                  1.2                               47.8
# 8                                  1.7                               36.2
# 9                                  1.0                               57.4
# 10                                 3.2                               46.2
# 11                                 0.3                               46.7
# 12                                 2.7                               53.0
# 13                                 6.1                               74.1
# 14                                 5.5                               50.5
# 15                                 2.0                               34.4
# 16                                 0.9                               46.9
# 17                                 NaN                                NaN
# 18                                 0.6                               33.3
# 19                                 2.6                               46.8
# 20                                 0.1                               37.5
# 21                                 1.6                               29.3
# 22                                 1.0                               27.9
# 23                                 0.2                               50.0
# 24                                 0.9                               53.6
# 25                                 2.0                               49.6
# 26                                 2.5                               53.8
# 27                                 1.0                               48.5
# 28                                 2.2                               73.8
# 29                                 NaN                                NaN
# 30                                 0.2                              100.0
# 31                                 0.0                               20.0
# 32                                 0.2                               50.0
# 33                                 1.9                               71.8
# 34                                 2.5                               52.7
# 35                                 0.9                               77.8
# 36                                 2.6                               53.4
# 37                                 2.6                               45.1
# 38                                 NaN                                NaN
# 39                                 1.3                               37.5
# 40                                 2.7                               51.0
# 41                                 0.9                               34.3
# 42                                 1.2                               47.1
# 43                                 0.1                              100.0
# 44                                 2.3                               64.9
# 45                                 2.1                               59.3
# 46                                 0.4                               52.6
# 47                                 2.3                               41.7
# 48                                 1.1                               42.9
# 49                                 2.0                               64.4
#
#     Minutes_passing_y  Matches_passing_y Country_passing_y
# 0              2314.0               27.0               MAR
# 1               713.0               23.0               ALG
# 2               921.0               28.0               MAR
# 3              1258.0               34.0               ESP
# 4              1695.0               20.0               GHA
# 5              1397.0               23.0               BRA
# 6              1749.0               31.0               ESP
# 7              2485.0               36.0               ESP
# 8              1120.0               21.0               ESP
# 9              2350.0               33.0               ESP
# 10             2706.0               34.0               ESP
# 11             1807.0               28.0               ESP
# 12             1490.0               27.0               ESP
# 13             3201.0               37.0               ESP
# 14             2536.0               30.0               ESP
# 15              970.0               21.0               ESP
# 16             1581.0               35.0               ESP
# 17                NaN                NaN               NaN
# 18             1285.0               31.0               ESP
# 19             2566.0               32.0               ESP
# 20             2491.0               34.0               NOR
# 21             2512.0               31.0               URU
# 22             1119.0               19.0               ESP
# 23              886.0               32.0               GRE
# 24             1436.0               29.0               ESP
# 25             2936.0               37.0               ESP
# 26             1023.0               23.0               ESP
# 27             2863.0               36.0               ESP
# 28             1990.0               30.0               DEN
# 29                NaN                NaN               NaN
# 30              730.0               19.0               POR
# 31             2449.0               33.0               CRO
# 32              866.0               19.0               HON
# 33             2654.0               33.0               FRA
# 34             2436.0               33.0               ESP
# 35              720.0               27.0               ESP
# 36             2198.0               26.0               ESP
# 37             2707.0               33.0               GER
# 38                NaN                NaN               NaN
# 39             1463.0               29.0               ESP
# 40             1691.0               19.0               EQG
# 41             1240.0               21.0               ESP
# 42             1229.0               29.0               RUS
# 43             2605.0               36.0               UKR
# 44             1987.0               27.0               FRA
# 45             2784.0               35.0               BEL
# 46             2307.0               31.0               ESP
# 47              193.0               19.0               CPV
# 48             1450.0               26.0               ESP
# 49             1688.0               29.0               ESP

# %%
scoring_df.head(50)
# Out:
#     Rank                Player                Team  Goals per 90  Total Goals  \
# 0      1      Cristhian Stuani              Girona          1.04          9.0
# 1      2                  Bebé      Rayo Vallecano          0.93          2.0
# 2      3          Artem Dovbyk              Girona          0.83         24.0
# 3      4     Alexander Sørloth          Villarreal          0.83         23.0
# 4      5       Jude Bellingham         Real Madrid          0.74         19.0
# 5      6       Vinicius Junior         Real Madrid          0.72         15.0
# 6      7         Álvaro Morata  Atlético de Madrid          0.71         15.0
# 7      8   Anastasios Douvikas       Celta de Vigo          0.71          7.0
# 8      9    Robert Lewandowski           Barcelona          0.62         19.0
# 9     10          Ante Budimir             Osasuna          0.62         17.0
# 10    11         Borja Mayoral              Getafe          0.62         15.0
# 11    12     José Luis Morales          Villarreal          0.61          7.0
# 12    13     Youssef En-Nesyri             Sevilla          0.56         16.0
# 13    14        Gorka Guruzeta       Athletic Club          0.56         14.0
# 14    15     Antoine Griezmann  Atlético de Madrid          0.54         16.0
# 15    16                Joselu         Real Madrid          0.54         10.0
# 16    17          Ángel Correa  Atlético de Madrid          0.53          9.0
# 17    18         Ferran Torres           Barcelona          0.52          7.0
# 18    19         Memphis Depay  Atlético de Madrid          0.51          5.0
# 19    20          Fermin Lopez           Barcelona          0.50          8.0
# 20    21        Cristian Portu              Girona          0.50          7.0
# 21    22          Marc Cardona          Las Palmas          0.50          4.0
# 22    23          Willian José          Real Betis          0.46         10.0
# 23    24           Brahim Diaz         Real Madrid          0.46          8.0
# 24    25         Darwin Machis               Cádiz          0.46          4.0
# 25    26           Abdon Prats            Mallorca          0.43          6.0
# 26    27  Jørgen Strand Larsen       Celta de Vigo          0.41         13.0
# 27    28            Joao Félix           Barcelona          0.41          7.0
# 28    29           Myrto Uzuni          Granada CF          0.40         11.0
# 29    30         Gerard Moreno          Villarreal          0.40         10.0
# 30    31      Samuel Omorodion              Alavés          0.40          9.0
# 31    32        Alex Berenguer       Athletic Club          0.40          7.0
# 32    33           Raul Garcia             Osasuna          0.40          6.0
# 33    34        Dodi Lukebakio             Sevilla          0.40          5.0
# 34    35             Hugo Duro         Valencia CF          0.39         13.0
# 35    36        Sergio Arribas             Almería          0.39          9.0
# 36    37              Raphinha           Barcelona          0.39          6.0
# 37    38        Inaki Williams       Athletic Club          0.38         12.0
# 38    39               Rodrygo         Real Madrid          0.38         10.0
# 39    40       Mikel Oyarzabal       Real Sociedad          0.38          9.0
# 40    41           André Silva       Real Sociedad          0.37          3.0
# 41    42      Valery Fernández              Girona          0.37          2.0
# 42    43           Ayoze Pérez          Real Betis          0.35          9.0
# 43    44      Viktor Tsigankov              Girona          0.35          8.0
# 44    45        Bryan Zaragoza          Granada CF          0.33          6.0
# 45    46                  Isco          Real Betis          0.31          8.0
# 46    47        Anthony Lozano             Almería          0.31          3.0
# 47    48          Iker Muniain       Athletic Club          0.31          2.0
# 48    49            Iago Aspas       Celta de Vigo          0.30          9.0
# 49    50         Takefusa Kubo       Real Sociedad          0.29          7.0
#
#     Minutes  Matches Country  Expected Goals (xG)  Actual Goals  \
# 0       782       31     URU                  NaN           NaN
# 1       193       19     CPV                  NaN           NaN
# 2      2605       36     UKR                  NaN           NaN
# 3      2491       34     NOR                  NaN           NaN
# 4      2323       28     ENG                  NaN           NaN
# 5      1872       26     BRA                  NaN           NaN
# 6      1909       32     ESP                  NaN           NaN
# 7       886       32     GRE                  NaN           NaN
# 8      2758       35     POL                  NaN           NaN
# 9      2449       33     CRO                  NaN           NaN
# 10     2162       27     ESP                  NaN           NaN
# 11     1037       29     ESP                  NaN           NaN
# 12     2573       33     MAR                  NaN           NaN
# 13     2240       32     ESP                  NaN           NaN
# 14     2654       33     FRA                  NaN           NaN
# 15     1676       34     ESP                  NaN           NaN
# 16     1525       32     ARG                  NaN           NaN
# 17     1204       29     ESP                  NaN           NaN
# 18      888       23     NED                  NaN           NaN
# 19     1444       31     ESP                  NaN           NaN
# 20     1271       36     ESP                  NaN           NaN
# 21      724       26     ESP                  NaN           NaN
# 22     1978       33     BRA                  NaN           NaN
# 23     1551       31     MAR                  NaN           NaN
# 24      782       21     VEN                  NaN           NaN
# 25     1258       34     ESP                  NaN           NaN
# 26     2887       37     NOR                  NaN           NaN
# 27     1542       30     POR                  NaN           NaN
# 28     2459       34     ALB                  NaN           NaN
# 29     2229       30     ESP                  NaN           NaN
# 30     2003       35     ESP                  NaN           NaN
# 31     1581       35     ESP                  NaN           NaN
# 32     1347       35     ESP                  NaN           NaN
# 33     1124       23     BEL                  NaN           NaN
# 34     2994       37     ESP                  NaN           NaN
# 35     2055       34     ESP                  NaN           NaN
# 36     1370       28     BRA                  NaN           NaN
# 37     2855       34     GHA                  NaN           NaN
# 38     2388       34     BRA                  NaN           NaN
# 39     2157       33     ESP                  NaN           NaN
# 40      730       19     POR                  NaN           NaN
# 41      486       27     ESP                  NaN           NaN
# 42     2307       31     ESP                  NaN           NaN
# 43     2067       30     UKR                  NaN           NaN
# 44     1640       21     ESP                  NaN           NaN
# 45     2338       29     ESP                  NaN           NaN
# 46      866       19     HON                  NaN           NaN
# 47      585       20     ESP                  NaN           NaN
# 48     2715       35     ESP                  NaN           NaN
# 49     2155       30     JPN                  NaN           NaN
#
#     Shots on Target per 90  Shot Accuracy (%)  Goals  Penalties  \
# 0                      NaN                NaN    NaN        NaN
# 1                      NaN                NaN    NaN        NaN
# 2                      NaN                NaN    NaN        NaN
# 3                      NaN                NaN    NaN        NaN
# 4                      NaN                NaN    NaN        NaN
# 5                      NaN                NaN    NaN        NaN
# 6                      NaN                NaN    NaN        NaN
# 7                      NaN                NaN    NaN        NaN
# 8                      NaN                NaN    NaN        NaN
# 9                      NaN                NaN    NaN        NaN
# 10                     NaN                NaN    NaN        NaN
# 11                     NaN                NaN    NaN        NaN
# 12                     NaN                NaN    NaN        NaN
# 13                     NaN                NaN    NaN        NaN
# 14                     NaN                NaN    NaN        NaN
# 15                     NaN                NaN    NaN        NaN
# 16                     NaN                NaN    NaN        NaN
# 17                     NaN                NaN    NaN        NaN
# 18                     NaN                NaN    NaN        NaN
# 19                     NaN                NaN    NaN        NaN
# 20                     NaN                NaN    NaN        NaN
# 21                     NaN                NaN    NaN        NaN
# 22                     NaN                NaN    NaN        NaN
# 23                     NaN                NaN    NaN        NaN
# 24                     NaN                NaN    NaN        NaN
# 25                     NaN                NaN    NaN        NaN
# 26                     NaN                NaN    NaN        NaN
# 27                     NaN                NaN    NaN        NaN
# 28                     NaN                NaN    NaN        NaN
# 29                     NaN                NaN    NaN        NaN
# 30                     NaN                NaN    NaN        NaN
# 31                     NaN                NaN    NaN        NaN
# 32                     NaN                NaN    NaN        NaN
# 33                     NaN                NaN    NaN        NaN
# 34                     NaN                NaN    NaN        NaN
# 35                     NaN                NaN    NaN        NaN
# 36                     NaN                NaN    NaN        NaN
# 37                     NaN                NaN    NaN        NaN
# 38                     NaN                NaN    NaN        NaN
# 39                     NaN                NaN    NaN        NaN
# 40                     NaN                NaN    NaN        NaN
# 41                     NaN                NaN    NaN        NaN
# 42                     NaN                NaN    NaN        NaN
# 43                     NaN                NaN    NaN        NaN
# 44                     NaN                NaN    NaN        NaN
# 45                     NaN                NaN    NaN        NaN
# 46                     NaN                NaN    NaN        NaN
# 47                     NaN                NaN    NaN        NaN
# 48                     NaN                NaN    NaN        NaN
# 49                     NaN                NaN    NaN        NaN
#
#     Goals Conceded per 90  Total Goals Conceded  \
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                     NaN                   NaN
# 4                     NaN                   NaN
# 5                     NaN                   NaN
# 6                     NaN                   NaN
# 7                     NaN                   NaN
# 8                     NaN                   NaN
# 9                     NaN                   NaN
# 10                    NaN                   NaN
# 11                    NaN                   NaN
# 12                    NaN                   NaN
# 13                    NaN                   NaN
# 14                    NaN                   NaN
# 15                    NaN                   NaN
# 16                    NaN                   NaN
# 17                    NaN                   NaN
# 18                    NaN                   NaN
# 19                    NaN                   NaN
# 20                    NaN                   NaN
# 21                    NaN                   NaN
# 22                    NaN                   NaN
# 23                    NaN                   NaN
# 24                    NaN                   NaN
# 25                    NaN                   NaN
# 26                    NaN                   NaN
# 27                    NaN                   NaN
# 28                    NaN                   NaN
# 29                    NaN                   NaN
# 30                    NaN                   NaN
# 31                    NaN                   NaN
# 32                    NaN                   NaN
# 33                    NaN                   NaN
# 34                    NaN                   NaN
# 35                    NaN                   NaN
# 36                    NaN                   NaN
# 37                    NaN                   NaN
# 38                    NaN                   NaN
# 39                    NaN                   NaN
# 40                    NaN                   NaN
# 41                    NaN                   NaN
# 42                    NaN                   NaN
# 43                    NaN                   NaN
# 44                    NaN                   NaN
# 45                    NaN                   NaN
# 46                    NaN                   NaN
# 47                    NaN                   NaN
# 48                    NaN                   NaN
# 49                    NaN                   NaN
#
#     Expected Goals on Target (xGOT)
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# 5                               NaN
# 6                               NaN
# 7                               NaN
# 8                               NaN
# 9                               NaN
# 10                              NaN
# 11                              NaN
# 12                              NaN
# 13                              NaN
# 14                              NaN
# 15                              NaN
# 16                              NaN
# 17                              NaN
# 18                              NaN
# 19                              NaN
# 20                              NaN
# 21                              NaN
# 22                              NaN
# 23                              NaN
# 24                              NaN
# 25                              NaN
# 26                              NaN
# 27                              NaN
# 28                              NaN
# 29                              NaN
# 30                              NaN
# 31                              NaN
# 32                              NaN
# 33                              NaN
# 34                              NaN
# 35                              NaN
# 36                              NaN
# 37                              NaN
# 38                              NaN
# 39                              NaN
# 40                              NaN
# 41                              NaN
# 42                              NaN
# 43                              NaN
# 44                              NaN
# 45                              NaN
# 46                              NaN
# 47                              NaN
# 48                              NaN
# 49                              NaN

# %%
defensive_df.head()
# Out:
#    Rank                 Player        Team  Clean Sheets  Goals Conceded  \
# 0   NaN        Aaron Escandell  Las Palmas           NaN             NaN
# 1   NaN       Abdelkabir Abqar      Alavés           NaN             NaN
# 2   NaN    Abderrahman Rebbach      Alavés           NaN             NaN
# 3   NaN  Abdessamad Ezzalzouli  Real Betis           NaN             NaN
# 4   NaN            Abdon Prats    Mallorca           NaN             NaN
#
#    Minutes  Matches Country  Rank_defensive_1  Successful Dribbles per 90  \
# 0      NaN      NaN     NaN               NaN                         NaN
# 1      NaN      NaN     NaN             289.0                         0.1
# 2      NaN      NaN     NaN              72.0                         1.3
# 3      NaN      NaN     NaN              21.0                         2.2
# 4      NaN      NaN     NaN             170.0                         0.6
#
#    ...  Yellow Cards_defensive_8  Minutes_defensive_8  Matches_defensive_8  \
# 0  ...                       0.0                152.0                  2.0
# 1  ...                       NaN                  NaN                  NaN
# 2  ...                       NaN                  NaN                  NaN
# 3  ...                       NaN                  NaN                  NaN
# 4  ...                       NaN                  NaN                  NaN
#
#   Country_defensive_8  Rank_defensive_9  Yellow Cards_defensive_9  \
# 0                 ESP               NaN                       NaN
# 1                 NaN              10.0                      10.0
# 2                 NaN             378.0                       1.0
# 3                 NaN             378.0                       1.0
# 4                 NaN             229.0                       3.0
#
#    Red Cards_defensive_9  Minutes_defensive_9  Matches_defensive_9  \
# 0                    NaN                  NaN                  NaN
# 1                    0.0               2314.0                 27.0
# 2                    0.0                713.0                 23.0
# 3                    0.0                921.0                 28.0
# 4                    0.0               1258.0                 34.0
#
#   Country_defensive_9
# 0                 NaN
# 1                 MAR
# 2                 ALG
# 3                 MAR
# 4                 ESP
#
# [5 rows x 62 columns]

# %%
assists_df.head()
# Out:
#     Rank                 Player        Team  Assists  Secondary Assists  \
# 0    NaN        Aaron Escandell  Las Palmas      NaN                NaN
# 1    NaN       Abdelkabir Abqar      Alavés      NaN                NaN
# 2    NaN    Abderrahman Rebbach      Alavés      NaN                NaN
# 3    NaN  Abdessamad Ezzalzouli  Real Betis      NaN                NaN
# 4  199.0            Abdon Prats    Mallorca      1.0                1.2
#
#    Minutes  Matches Country  Rank_assists  Expected Assists (xA)  \
# 0      NaN      NaN     NaN         478.0                    0.0
# 1      NaN      NaN     NaN         389.0                    0.2
# 2      NaN      NaN     NaN         152.0                    1.7
# 3      NaN      NaN     NaN         316.0                    0.5
# 4   1258.0     34.0     ESP         190.0                    1.2
#
#    Actual Assists  Minutes_assists  Matches_assists Country_assists  \
# 0             0.0            152.0              2.0             ESP
# 1             0.0           2314.0             27.0             MAR
# 2             0.0            713.0             23.0             ALG
# 3             0.0            921.0             28.0             MAR
# 4             1.0           1258.0             34.0             ESP
#
#    Rank_assists  Big Chances Created  Total Assists  Minutes_assists  \
# 0           NaN                  NaN            NaN              NaN
# 1           NaN                  NaN            NaN              NaN
# 2         226.0                  2.0            0.0            713.0
# 3           NaN                  NaN            NaN              NaN
# 4         120.0                  4.0            1.0           1258.0
#
#    Matches_assists Country_assists
# 0              NaN             NaN
# 1              NaN             NaN
# 2             23.0             ALG
# 3              NaN             NaN
# 4             34.0             ESP

# %%
misc_df.head()
# Out:
#    Rank                 Player        Team  Red Cards  Yellow Cards  Minutes  \
# 0  72.0        Aaron Escandell  Las Palmas        1.0           0.0    152.0
# 1   NaN       Abdelkabir Abqar      Alavés        NaN           NaN      NaN
# 2   NaN    Abderrahman Rebbach      Alavés        NaN           NaN      NaN
# 3   NaN  Abdessamad Ezzalzouli  Real Betis        NaN           NaN      NaN
# 4   NaN            Abdon Prats    Mallorca        NaN           NaN      NaN
#
#    Matches Country  Rank_misc  Yellow Cards_misc  Red Cards_misc  \
# 0      2.0     ESP        NaN                NaN             NaN
# 1      NaN     NaN       10.0               10.0             0.0
# 2      NaN     NaN      378.0                1.0             0.0
# 3      NaN     NaN      378.0                1.0             0.0
# 4      NaN     NaN      229.0                3.0             0.0
#
#    Minutes_misc  Matches_misc Country_misc  Rank_misc  FotMob Rating  \
# 0           NaN           NaN          NaN        NaN            NaN
# 1        2314.0          27.0          MAR      224.0           6.69
# 2         713.0          23.0          ALG      305.0           6.32
# 3         921.0          28.0          MAR      293.0           6.42
# 4        1258.0          34.0          ESP      288.0           6.45
#
#    Player of the Match Awards  Minutes_misc  Matches_misc Country_misc
# 0                         NaN           NaN           NaN          NaN
# 1                         0.0        2314.0          27.0          MAR
# 2                         0.0         713.0          23.0          ALG
# 3                         0.0         921.0          28.0          MAR
# 4                         0.0        1258.0          34.0          ESP

# %%
# Function to calculate the percentage of null values for a DataFrame
def calculate_null_percentage(df, df_name):
    null_percentage = df.isnull().mean() * 100
    print(f"\n--- Null Percentage for {df_name} ---")
    print(null_percentage[null_percentage > 0])  # Only display columns with nulls

# Calculate null percentages for each DataFrame
calculate_null_percentage(passing_df, "Passing Statistics")
calculate_null_percentage(scoring_df, "Scoring Statistics")
calculate_null_percentage(defensive_df, "Defensive Statistics")
calculate_null_percentage(assists_and_creativity_df, "Assists and Creativity")
calculate_null_percentage(misc_performance_df, "Miscellaneous Performance Metrics")
# Out:
# --- Null Percentage for Passing Statistics ---
# Rank_passing_y                        5.688623
# Accurate Long Balls per 90_passing    5.688623
# Successful Long Balls (%)_passing     5.688623
# Minutes_passing_y                     5.688623
# Matches_passing_y                     5.688623
# Country_passing_y                     5.688623
# dtype: float64
#
# --- Null Percentage for Scoring Statistics ---
# Goals per 90                       87.104338
# Total Goals                        87.104338
# Expected Goals (xG)                71.512309
# Actual Goals                       47.596717
# Shots on Target per 90             82.590856
# Shot Accuracy (%)                  82.590856
# Goals                              83.821805
# Penalties                          83.821805
# Goals Conceded per 90              98.886284
# Total Goals Conceded               98.886284
# Expected Goals on Target (xGOT)    76.084408
# dtype: float64
#
# --- Null Percentage for Defensive Statistics ---
# Rank                          93.762994
# Clean Sheets                  93.762994
# Goals Conceded                93.762994
# Minutes                       93.762994
# Matches                       93.762994
# Country                       93.762994
# Rank_defensive_1              34.095634
# Successful Dribbles per 90    34.095634
# Dribble Success Rate (%)      34.095634
# Minutes_defensive_1           34.095634
# Matches_defensive_1           34.095634
# Country_defensive_1           34.095634
# Rank_defensive_2              31.600832
# Clearances per 90             31.600832
# Total Clearances              31.600832
# Minutes_defensive_2           31.600832
# Matches_defensive_2           31.600832
# Country_defensive_2           31.600832
# Rank_defensive_3              32.640333
# Fouls Committed per 90        32.640333
# Yellow Cards                  32.640333
# Minutes_defensive_3           32.640333
# Matches_defensive_3           32.640333
# Country_defensive_3           32.640333
# Rank_defensive_4              35.135135
# Interceptions per 90          35.135135
# Total Interceptions           35.135135
# Minutes_defensive_4           35.135135
# Matches_defensive_4           35.135135
# Country_defensive_4           35.135135
# Rank_defensive_5              42.619543
# Blocks per 90                 42.619543
# Total Blocks                  42.619543
# Minutes_defensive_5           42.619543
# Matches_defensive_5           42.619543
# Country_defensive_5           42.619543
# Rank_defensive_6              32.432432
# Tackles per 90                32.432432
# Tackle Success Rate (%)       32.432432
# Minutes_defensive_6           32.432432
# Matches_defensive_6           32.432432
# Country_defensive_6           32.432432
# Rank_defensive_7              96.049896
# Saves per 90                  96.049896
# Total Saves                   96.049896
# Minutes_defensive_7           96.049896
# Matches_defensive_7           96.049896
# Country_defensive_7           96.049896
# Rank_defensive_8              83.575884
# Red Cards                     83.575884
# Yellow Cards_defensive_8      83.575884
# Minutes_defensive_8           83.575884
# Matches_defensive_8           83.575884
# Country_defensive_8           83.575884
# Rank_defensive_9               5.613306
# Yellow Cards_defensive_9       5.613306
# Red Cards_defensive_9          5.613306
# Minutes_defensive_9            5.613306
# Matches_defensive_9            5.613306
# Country_defensive_9            5.613306
# dtype: float64
#
# --- Null Percentage for Assists and Creativity ---
# Expected Assists (xA)       74.392361
# Actual Assists              74.392361
# Big Chances Created         85.286458
# Total Assists               85.286458
# Assists                     88.194444
# Secondary Assists           88.194444
# Expected Assists per 90     85.503472
# Actual Assists per 90       85.503472
# Big Chances Missed          87.500000
# Shot Conversion Rate (%)    87.500000
# Chances Created             79.123264
# Chances Created per 90      79.123264
# dtype: float64
#
# --- Null Percentage for Miscellaneous Performance Metrics ---
# FotMob Rating                 61.173533
# Player of the Match Awards    61.173533
# Saves per 90                  97.627965
# Total Saves                   97.627965
# Penalties Won                 92.259675
# Fouls Won per 90              92.259675
# Penalties Conceded            88.264669
# Total Matches                 88.264669
# Shots per 90                  60.674157
# Shot Conversion Rate (%)      60.674157
# dtype: float64
